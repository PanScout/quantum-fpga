# %%
import numpy as np
import math
import plotly.graph_objects as go
import plotly.express as px
from scipy.ndimage import gaussian_filter

# === Configuration Variables ===
num_frames = 6000          # Number of time frames to generate.
t_min = 0                 # Start time.
t_max = 5                 # End time.
vector_length = 1024      # Number of elements per vector (should be a perfect square)
height_scale = 10.0       # Scaling factor for the magnitude
transition_duration = int(1000/60)  # about 42 ms per frame
grid_spacing = 2          # Spacing factor between points on the grid.
sigma = 1                 # Gaussian smoothing sigma for both surface and phase
# ================================

# Generate the base random complex vector.
V = 2 * (np.random.rand(vector_length) + 1j * np.random.rand(vector_length))

# Define the maximum magnitude we want at the top of the z-axis.
# (This can be based on your initial data or set to an arbitrary value.)
max_magnitude = height_scale * np.max(np.abs(V))

def vector_to_near_square(vec):
    """
    Reshape a 1D numpy array into a square matrix.
    Assumes that the total number of elements is a perfect square.
    """
    vec = np.ravel(vec)
    L = vec.size
    s = int(math.sqrt(L))
    if s * s == L:
        return vec.reshape((s, s))
    for r in range(s, 0, -1):
        if L % r == 0:
            c = L // r
            return vec.reshape((r, c))
    raise ValueError("No factors found for vector length.")

def create_surface(matrix):
    """
    Given a square matrix of complex numbers, create a Plotly Surface.
    
    - The Z-axis (height) is given by the smoothed magnitude (|v(t)|) scaled by height_scale,
      then normalized so that the maximum value becomes max_magnitude.
    - The color is based on a smoothed phase mapping:
      The phase is first smoothed with a Gaussian filter, then normalized from [-π, π] to [0,1],
      multiplied by 3 and taken modulo 1.
    
    A Gaussian filter is applied to both the magnitude and the phase.
    """
    # Compute the coarse grid data for magnitude.
    Z_coarse = height_scale * np.abs(matrix)
    Z_smooth = gaussian_filter(Z_coarse, sigma=sigma)
    
    # Normalize the smoothed magnitude so its maximum equals max_magnitude.
    if np.max(Z_smooth) > 0:
        Z_normalized = Z_smooth * (max_magnitude / np.max(Z_smooth))
    else:
        Z_normalized = Z_smooth
    
    # Compute and smooth the phase.
    phase = np.angle(matrix)
    phase_smoothed = gaussian_filter(phase, sigma=sigma)
    # Map the smoothed phase to a normalized color value.
    C_coarse = ((phase_smoothed + np.pi) / (2 * np.pi) * 3) % 1
    C_smooth = gaussian_filter(C_coarse, sigma=sigma)
    
    # Determine grid dimensions.
    rows, cols = matrix.shape
    # Center the grid coordinates.
    center_x = ((cols - 1) * grid_spacing) / 2
    center_y = ((rows - 1) * grid_spacing) / 2
    x = np.arange(cols) * grid_spacing - center_x
    y = np.arange(rows) * grid_spacing - center_y

    surface = go.Surface(
        x=x,
        y=y,
        z=Z_normalized,
        surfacecolor=C_smooth,
        colorscale=px.colors.sequential.Rainbow,
        cmin=0,
        cmax=1,
        colorbar=dict(
            title="Phase (norm.)",
            tickvals=[0, 0.5, 1],
            ticktext=["0", "0.5", "1"]
        ),
        contours={
            "z": {"show": True,
                  "start": 0,
                  "end": max_magnitude,
                  "size": max_magnitude / 10,
                  "color": "black",
                  "width": 1}
        },
    )
    return surface

# Precompute time values.
t_values = np.linspace(t_min, t_max, num_frames)

# (Optional) Compute a desired average magnitude from the initial vector if needed.
desired_avg = np.mean(np.abs(V))

# Generate frames: each frame evolves the vector as v(t) = V * exp(i*V*t)
frames = []
for idx, t in enumerate(t_values):
    # Evolve the vector.
    v_t = V * np.exp(1j * V * t)
    # Normalize so that the overall average remains constant if desired.
    current_avg = np.mean(np.abs(v_t))
    v_t = v_t * (desired_avg / current_avg)
    
    matrix = vector_to_near_square(v_t)
    surface = create_surface(matrix)
    frames.append(go.Frame(data=[surface], name=str(idx),
                           layout_title_text=f"Time Evolution: t = {t:.2f}"))

# Create the initial frame at t = t_min.
v0 = V * np.exp(1j * V * t_values[0])
v0 = v0 * (desired_avg / np.mean(np.abs(v0)))  # normalize initial frame
init_matrix = vector_to_near_square(v0)
init_surface = create_surface(init_matrix)

# Calculate fixed ranges for the x- and y-axes based on the centered grid.
s = int(math.sqrt(vector_length))  # For a perfect square, s x s matrix.
center = ((s - 1) * grid_spacing) / 2
x_range = [-center, center]
y_range = [-center, center]
# Set the z-axis range to [0, max_magnitude].
z_range = [0, max_magnitude]

# Set a fixed aspect ratio for the 3D scene.
aspectratio = dict(
    x=x_range[1] - x_range[0],
    y=y_range[1] - y_range[0],
    z=z_range[1] - z_range[0]
)

# Build the Plotly figure with an adjusted camera position.
fig = go.Figure(
    data=[init_surface],
    layout=go.Layout(
        template="plotly_white",
        title={
            "text": f"Time Evolution: t = {t_values[0]:.2f}",
            "x": 0.5,
            "xanchor": "center",
            "font": {"size": 22}
        },
        scene=dict(
            xaxis_title="X Index",
            yaxis_title="Y Index",
            zaxis_title="Magnitude",
            xaxis=dict(
                range=x_range,
                backgroundcolor="rgb(230,230,230)",
                gridcolor="white",
                showbackground=True,
                zerolinecolor="white"
            ),
            yaxis=dict(
                range=y_range,
                backgroundcolor="rgb(230,230,230)",
                gridcolor="white",
                showbackground=True,
                zerolinecolor="white"
            ),
            zaxis=dict(
                range=z_range,
                backgroundcolor="rgb(230,230,230)",
                gridcolor="white",
                showbackground=True,
                zerolinecolor="white"
            ),
            camera=dict(eye=dict(x=80, y=80, z=80)),
            aspectmode="manual",
            aspectratio=aspectratio
        ),
        margin=dict(l=80, r=80, t=80, b=80),
        width=900,
        height=900,
        updatemenus=[{
            "buttons": [
                {
                    "args": [None, {"frame": {"duration": transition_duration, "redraw": True},
                                     "transition": {"duration": transition_duration, "easing": "cubic-in-out"},
                                     "fromcurrent": True}],
                    "label": "Play",
                    "method": "animate"
                },
                {
                    "args": [[None], {"frame": {"duration": 0, "redraw": True},
                                       "mode": "immediate",
                                       "transition": {"duration": 0}}],
                    "label": "Pause",
                    "method": "animate"
                }
            ],
            "direction": "left",
            "pad": {"r": 10, "t": 87},
            "showactive": False,
            "type": "buttons",
            "x": 0.1,
            "xanchor": "right",
            "y": 0,
            "yanchor": "top"
        }],
        sliders=[{
            "active": 0,
            "currentvalue": {"prefix": "Frame: ", "font": {"size": 16}},
            "pad": {"t": 50},
            "steps": [
                {
                    "args": [[str(i)], {"frame": {"duration": transition_duration, "redraw": True},
                                          "transition": {"duration": transition_duration, "easing": "cubic-in-out"},
                                          "mode": "immediate"}],
                    "label": f"t = {t:.2f}",
                    "method": "animate"
                }
                for i, t in enumerate(t_values)
            ]
        }],
        transition=dict(duration=transition_duration, easing="cubic-in-out")
    ),
    frames=frames
)

fig.show()

# %%
# If not already installed, run this cell:
# !pip install joblib

import os
import subprocess
import numpy as np
import math
from scipy.ndimage import gaussian_filter
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from matplotlib import cm
from joblib import Parallel, delayed

# --- Worker Function ---
def process_frame(frame_index, X, Y, Z_data, C_data, t_values, max_magnitude, x_max, y_max, cmap_name, frames_dir):
    """
    Creates a 3D surface plot for the specified frame and saves it.
    """
    # Re-import matplotlib in this worker
    import matplotlib
    matplotlib.use('Agg')
    import matplotlib.pyplot as plt
    from matplotlib import cm

    # Get the colormap by name (avoid pickling issues with cmap objects)
    cmap_obj = cm.get_cmap(cmap_name)
    
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    ax.view_init(elev=45, azim=45)
    
    # Set axis limits and labels
    ax.set(xlim=(-x_max, x_max),
           ylim=(-y_max, y_max),
           zlim=(0, max_magnitude),
           xlabel='X', ylabel='Y', zlabel='Magnitude')
    
    # Plot the surface
    ax.plot_surface(
        X, Y, Z_data[frame_index],
        facecolors=cmap_obj(C_data[frame_index][:-1, :-1]),
        rstride=1, cstride=1, shade=True,
        edgecolor='none', antialiased=True
    )
    # Set the title for this frame
    ax.set_title(f"Time Evolution: t = {t_values[frame_index]:.2f}")
    
    # Save the frame image
    filename = os.path.join(frames_dir, f"frame_{frame_index:04d}.png")
    fig.savefig(filename)
    plt.close(fig)
    return filename

# --- Main Code (run this cell as a whole) ---
# Configuration variables
num_frames = 300          # Number of frames for the animation
t_min = 0
t_max = 5
vector_length = 1024      # Must be a perfect square (e.g. 1024 = 32x32)
height_scale = 10.0
grid_spacing = 2
sigma = 1
fps = 30                  # Frames per second for the output video

# Precompute frame data
V = 2 * (np.random.rand(vector_length) + 1j * np.random.rand(vector_length))
desired_avg = np.mean(np.abs(V))

# Determine grid size (assumes vector_length is a perfect square)
s = int(math.sqrt(vector_length))
def vector_to_near_square(vec):
    return vec.reshape((s, s))

t_values = np.linspace(t_min, t_max, num_frames)

# Allocate arrays for magnitude (Z) and phase (C) data
Z_data = np.empty((num_frames, s, s))
C_data = np.empty((num_frames, s, s))

max_magnitude = height_scale * np.max(np.abs(V))

for i, t in enumerate(t_values):
    v_t = V * np.exp(1j * V * t)
    v_t *= desired_avg / np.mean(np.abs(v_t))
    matrix = vector_to_near_square(v_t)
    
    Z = gaussian_filter(height_scale * np.abs(matrix), sigma)
    if np.max(Z) > 0:
        Z = Z * (max_magnitude / np.max(Z))
    Z_data[i] = Z
    
    phase_norm = (np.angle(matrix) + np.pi) / (2 * np.pi)
    phase_smoothed = gaussian_filter(phase_norm, sigma)
    C_data[i] = (phase_smoothed * 3) % 1

# Set up the plotting grid
x = np.arange(s) * grid_spacing - (s - 1) * grid_spacing / 2
y = np.arange(s) * grid_spacing - (s - 1) * grid_spacing / 2
X, Y = np.meshgrid(x, y)
x_max = x[-1]
y_max = y[-1]

# Use the colormap name (avoid pickling the object)
cmap_name = 'hsv'

# Create directory for frames
frames_dir = "frames"
os.makedirs(frames_dir, exist_ok=True)

print("Rendering frames concurrently using Joblib...")

# Render frames concurrently using Joblib
results = Parallel(n_jobs=-1, backend="multiprocessing")(
    delayed(process_frame)(frame_index, X, Y, Z_data, C_data, t_values, max_magnitude, x_max, y_max, cmap_name, frames_dir)
    for frame_index in range(num_frames)
)

# Check that frames were created
if results:
    print("\nAll frames saved in the 'frames' directory.")
else:
    print("No frames were rendered.")

# --- Stitch Frames Together Using ffmpeg ---
ffmpeg_cmd = [
    "ffmpeg",
    "-framerate", str(fps),
    "-i", os.path.join(frames_dir, "frame_%04d.png"),
    "-c:v", "h264_videotoolbox",  # Use the M1 hardware encoder
    "-pix_fmt", "yuv420p",
    "animation.mp4"
]

print("\nStitching frames into video using ffmpeg with h264_videotoolbox...")
subprocess.run(ffmpeg_cmd, check=True)
print("\nVideo saved as 'animation.mp4'.")

# %%
import os
import shutil
import subprocess
import time  # For timing
import numpy as np
import math
from scipy.ndimage import gaussian_filter
import plotly.graph_objects as go
import plotly.io as pio
from concurrent.futures import ThreadPoolExecutor
from numba import jit

# === Configuration ===
t_min, t_max = 0, 7
vector_length = 4096  # Must be a perfect square for reshaping (e.g., 64x64)
height_scale = 1
grid_spacing = 1
sigma = 1
fps = 60
max_workers = 6  # Optimal for I/O-bound tasks
num_frames = int(np.ceil(fps * (t_max - t_min)))
# ======================

# Configure Plotly once
pio.kaleido.scope.default_format = "png"
pio.kaleido.scope.mathjax = None
pio.kaleido.scope.default_scale = 2  # Reduce resolution for speed

# --- JIT-optimized computations ---
@jit(nopython=True, parallel=True)
def compute_vt(V, t_values, desired_avg):
    num_frames = len(t_values)
    vt = np.empty((V.shape[0], num_frames), dtype=np.complex128)
    for i in range(num_frames):
        t = t_values[i]
        # Compute time evolution
        exp_term = np.exp(1j * V * t)
        vt[:, i] = V * exp_term
        # Normalize to preserve the average magnitude over time
        current_avg = np.mean(np.abs(vt[:, i]))
        vt[:, i] *= desired_avg / current_avg
    return vt

# --- Vectorized Gaussian filtering ---
def vectorized_gaussian(data, sigma):
    return gaussian_filter(data, sigma=(sigma, sigma, 0), mode='nearest')

# --- Precompute All Data ---
print("Precomputing data...")
precompute_start = time.time()

# Create a random complex vector and compute its desired average magnitude
V = 2 * (np.random.rand(vector_length) + 1j * np.random.rand(vector_length))
desired_avg = np.mean(np.abs(V))
s = int(math.sqrt(vector_length))
t_values = np.linspace(t_min, t_max, num_frames)

# Compute all vt vectors in parallel (with normalization to preserve magnitude)
vt_all = compute_vt(V, t_values, desired_avg)

# Reshape the precomputed data into a 3D array for further processing
vt_3d = vt_all.reshape(s, s, num_frames)
abs_vt = np.abs(vt_3d)
Z_all = vectorized_gaussian(height_scale * abs_vt, sigma)
max_values = np.max(abs_vt, axis=(0, 1)) * height_scale
Z_all *= max_values / np.max(Z_all, axis=(0, 1))

# Process phases for surface color
phase = (np.angle(vt_3d) + np.pi) / (2 * np.pi)
C_all = (vectorized_gaussian(phase, sigma) * 3) % 1

precompute_time = time.time() - precompute_start
print(f"Precomputation completed in {precompute_time:.2f} seconds")

# Prepare grid for rendering
x_grid = y_grid = np.arange(s) * grid_spacing - (s - 1) * grid_spacing / 2
max_magnitude = np.max(Z_all)

# --- Optimized Rendering ---
def create_figure_template():
    fig = go.Figure()
    fig.update_layout(
        scene=dict(
            xaxis_range=[0, x_grid[-1]],
            yaxis_range=[0, y_grid[-1]],
            zaxis_range=[0, max_magnitude],
            aspectratio=dict(x=1, y=1, z=0.7)
        ),
        margin=dict(l=0, r=0, b=0, t=30)
    )
    return fig

def render_frame(args):
    frame, fig_template = args
    start_frame = time.time()
    try:
        fig = go.Figure(fig_template)
        fig.add_trace(go.Surface(
            z=Z_all[:, :, frame],
            surfacecolor=C_all[:, :, frame],
            colorscale='HSV',
            cmin=0,
            cmax=1,
            showscale=False
        ))
        fig.update_layout(title=f"Time Evolution: t = {t_values[frame]:.2f}")
        fig.write_image(f"frames/frame_{frame:04d}.png", engine="kaleido")
        frame_duration = time.time() - start_frame
        return frame, frame_duration
    except Exception as e:
        print(f"Error rendering frame {frame}: {str(e)}")
        return frame, None

# --- Main Workflow ---
if __name__ == "__main__":
    # Cleanup existing frames directory and create a new one
    shutil.rmtree("frames", ignore_errors=True)
    os.makedirs("frames", exist_ok=True)
    
    # Create figure template
    fig_template = create_figure_template().to_dict()
    
    # Render frames with thread pool
    print(f"Rendering {num_frames} frames with {max_workers} threads...")
    completed = 0
    last_frame_time = 0
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(render_frame, (i, fig_template)) 
                   for i in range(num_frames)]
        
        for future in futures:
            frame, frame_time = future.result()
            if frame_time is not None:
                last_frame_time = frame_time
            completed += 1
            print(f"Progress: {completed}/{num_frames} | Last frame: {last_frame_time:.2f} s", end='\r')
    
    # Encode video using ffmpeg
    print("\nEncoding video...")
    subprocess.run([
        "ffmpeg", "-y", "-framerate", str(fps),
        "-pattern_type", "glob", "-i", "frames/frame_*.png",
        "-c:v", "h264_videotoolbox", "-pix_fmt", "yuv420p",
        "-movflags", "+faststart", "animation.mp4"
    ], check=True)
    
    print("Done! Video saved as animation.mp4")
# Out:
# Precomputing data...
# Precomputation completed in 0.65 seconds
# Rendering 420 frames with 6 threads...
# Progress: 14/420 | Last frame: 10.16 s
